# %%
import pandas as pd

# Sample data
data = pd.read_csv(f"/Users/ratirajpandav/Downloads/archive-3/Data.csv")

# %%
data.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  7.440000e+03  7.554000e+03  8.386000e+03  7.773000e+03  7.802000e+03
# mean   1.360038e+09  1.382693e+09  2.462948e+09  2.862819e+09  3.141853e+09
# std    3.026207e+10  3.134835e+10  4.431332e+10  4.943750e+10  5.394760e+10
# min   -5.030042e+00 -2.730000e+01 -1.968504e+01 -1.227866e+01 -1.246499e+01
# 25%    5.042912e+01  4.980143e+01  4.338068e+01  5.030710e+01  5.033103e+01
# 50%    3.278500e+03  2.378000e+03  8.770000e+02  2.488000e+03  2.458500e+03
# 75%    1.712580e+05  1.662558e+05  1.454448e+05  1.887030e+05  1.924130e+05
# max    1.364643e+12  1.420440e+12  1.524573e+12  1.638187e+12  1.799675e+12
#
#                1965          1966          1967          1968          1969  \
# count  7.846000e+03  7.892000e+03  8.559000e+03  7.960000e+03  8.006000e+03
# mean   3.447357e+09  3.718499e+09  3.653649e+09  4.253763e+09  4.664587e+09
# ...

# %%
print(data.head())
# Out:
#   Country.Name Country.Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator.Name     Indicator.Code  \
# 0        Access to anti-retroviral drugs, female (%)  SH.HIV.ARTC.FE.ZS
# 1          Access to anti-retroviral drugs, male (%)  SH.HIV.ARTC.MA.ZS
# 2  Account at a financial institution, female (% ...       WP_time_01.3
# 3  Account at a financial institution, male (% ag...       WP_time_01.2
# 4  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
#
#          1960        1961        1962        1963        1964        1965  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.bar(data["Country.Name"], data["2015"], color = 'Blue')
plt.xlabel("2015")
plt.ylabel("Country")
plt.title("Bar Graph Representation")
plt.show()
